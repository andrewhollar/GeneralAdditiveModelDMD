# %%
import pandas as pd

# %%
pd.read_excel('normalized_data_Jan10(Exon_Malueka_Category_C-0_A-1).xlsx', index_col=0)
# Out:
#          9G8   ACC_AVE  ACC_BEST8    ACC_FL  ACC_LAST15  ACC_LAST8       ACP  \
# 0   0.394003  0.141058   0.240188  0.000000    0.000000   0.310838  0.073516
# 1   0.394003  0.299748   0.296703  0.000000    0.151261   0.179959  0.105561
# 2   0.394003  0.312343   0.318681  0.000000    0.411765   0.364008  0.136664
# 3   0.288703  0.397985   0.312402  0.000000    0.000000   0.016360  0.327992
# 4   0.288703  0.332494   0.051805  0.000000    0.008403   0.006135  0.360038
# 5   0.288703  0.173804   0.051805  0.000000    0.000000   0.004090  0.392083
# 6   0.288703  0.234257   0.051805  0.000000    0.000000   0.000000  0.423186
# 7   0.663180  0.219144   0.034537  0.000000    0.000000   0.024540  0.455231
# 8   0.663180  0.246851   0.690738  0.000000    0.016807   0.901840  0.487276
# 9   0.663180  0.236776   0.690738  0.000000    0.016807   0.030675  0.519321
# 10  0.663180  0.181360   0.690738  0.000000    0.000000   0.006135  0.551367
# ...

# %%
from pygam.datasets import wage
from pygam import LinearGAM, s, f
import numpy as np
import matplotlib.pyplot as plt

# %%
X, y = wage()
gam = LinearGAM(s(0, n_splines=5) + s(1) + f(2)).fit(X,y)

# %%
lam = np.logspace(-3, 5, 5)
lams = [lam] * 3


gam.gridsearch(X, y, lam = lams)
gam.summary()
# Out:
# 100% (125 of 125) |######################| Elapsed Time: 0:00:05 Time:  0:00:05
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                      9.2948
# Link Function:                     IdentityLink Log Likelihood:                                -24119.7277
# Number of Samples:                         3000 AIC:                                            48260.0451
#                                                 AICc:                                           48260.1229
#                                                 GCV:                                              1244.089
#                                                 Scale:                                           1237.1528
#                                                 Pseudo R-Squared:                                   0.2915
# ...

# %%
lams = np.random.rand(100,3)
lams = lams * 8 - 3
lams = np.exp(lams)


random_gam =  LinearGAM(s(0) + s(1) + f(2)).gridsearch(X, y, lam=lams)
random_gam.summary()
# Out:
# 100% (100 of 100) |######################| Elapsed Time: 0:00:04 Time:  0:00:04
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     16.1339
# Link Function:                     IdentityLink Log Likelihood:                                -24115.4437
# Number of Samples:                         3000 AIC:                                            48265.1553
#                                                 AICc:                                           48265.3637
#                                                 GCV:                                             1247.4577
#                                                 Scale:                                           1235.3877
#                                                 Pseudo R-Squared:                                   0.2941
# ...

# %%
for i, term in enumerate(gam.terms):
    if term.isintercept:
        continue

    XX = gam.generate_X_grid(term=i)
    pdep, confi = gam.partial_dependence(term=i, X=XX, width=0.95)

    plt.figure()
    plt.plot(XX[:, term.feature], pdep)
    plt.plot(XX[:, term.feature], confi, c='r', ls='--')
    plt.title(repr(term))
    plt.show()
